# %%
pip install "tensorflow>=2.0.0"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 740.5 kB/s eta 0:00:00MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.0/645.0 MB 6.5 MB/s eta 0:00:000m eta 0:00:010:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 8.7 MB/s eta 0:00:00m eta 0:00:010:01:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 8.8 MB/s eta 0:00:00m eta 0:00:010:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 9.1 MB/s eta 0:00:009.9 MB/s eta 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 4.1 MB/s eta 0:00:00m eta 0:00:010:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 3.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...

# %%
pip install "numpy==1.25"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 2.6 MB/s eta 0:00:00m eta 0:00:010:0101
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [33 lines of output]
#       Traceback (most recent call last):
#         File "/home/arunkumar/virtual-env/my-jupytrt-env/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/home/arunkumar/virtual-env/my-jupytrt-env/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from cvlib.object_detection import draw_bbox
import cvlib as cv
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 5
#       3 import numpy as np
#       4 from cvlib.object_detection import draw_bbox
# ----> 5 import cvlib as cv
#
# File ~/virtual-env/my-jupytrt-env/lib/python3.12/site-packages/cvlib/__init__.py:8
#       6 from .face_detection import detect_face
#       7 from .object_detection import detect_common_objects
# ----> 8 from .gender_detection import detect_gender
#       9 from .utils import get_frames, animate
#
# File ~/virtual-env/my-jupytrt-env/lib/python3.12/site-packages/cvlib/gender_detection.py:3
#       1 import os
#       2 import cv2
# ----> 3 from tensorflow.keras.utils import get_file
#       5 initialize = True
#       6 gd = None
#
# File ~/virtual-env/my-jupytrt-env/lib/python3.12/site-packages/tensorflow/__init__.py:49
#      46 from tensorflow.python import tf2 as _tf2
#      47 _tf2.enable()
# ...

# %%
im = cv2.imread(r'p4.jpg')
plt.imshow(im[:,:,::-1])

# %%
bbox, conf = cv.detect_face(im)
